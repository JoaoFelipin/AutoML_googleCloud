# %%
import os
import pandas as pd 
from pycaret.regression import *

# %%
features = ['age','bmi','children','smoker']
target = 'charges'

# %%
data = pd.read_csv('../data/insurance.csv')
data = data[[*features,target]]
data
# Out:
#       age     bmi  children smoker      charges
# 0      19  27.900         0    yes  16884.92400
# 1      18  33.770         1     no   1725.55230
# 2      28  33.000         3     no   4449.46200
# 3      33  22.705         0     no  21984.47061
# 4      32  28.880         0     no   3866.85520
# ...   ...     ...       ...    ...          ...
# 1333   50  30.970         3     no  10600.54830
# 1334   18  31.920         0     no   2205.98080
# 1335   18  36.850         0     no   1629.83350
# 1336   21  25.800         0     no   2007.94500
# 1337   61  29.070         0    yes  29141.36030
#
# [1338 rows x 5 columns]

# %%
s = setup(data,target='charges',session_id=2023)
# Out:
# <style type="text/css">
# #T_d18f8_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d18f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d18f8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d18f8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d18f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d18f8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d18f8_row0_col1" class="data row0 col1" >2023</td>
#     </tr>
#     <tr>
#       <th id="T_d18f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d18f8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d18f8_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_d18f8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_bbd5b th {
#   text-align: left;
# }
# ...
